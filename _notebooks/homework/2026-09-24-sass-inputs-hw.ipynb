# %% [raw]
# ---
# layout: post
# title: SASS Inputs Review HW
# categories: [SASS]
# lesson_language: SASS
# lesson_topic: Inputs HW
# lesson_part: interactive
# lesson_type: lesson
# codemirror: true
# permalink: /sass/inputs-hw-v2/
# author: Raymond L
# ---

# %% [markdown]
# ## Popcorn Hack
#
# Both fields use `ocs__input`. The first is a compact plain box where a volunteer types their first name. The second is a big gradient box for looking up PVO resources.

# %% [markdown]
# {% capture challenge1 %}
# Popcorn Hack: a compact first name box and a big gradient search box. Hit Run and type something in both.
# {% endcapture %}
#
# {% capture code1 %}
# // Update the HTML inside the quotes, then hit Run.
# outputElement.innerHTML = [
#   '<p>',
#   '  <label for="v2-popcorn-volunteer-first-name">Your first name</label><br>',
#   '  <input id="v2-popcorn-volunteer-first-name" type="text" class="ocs__input small" placeholder="Your First Name">',
#   '</p>',
#   '<p>',
#   '  <label for="v2-pvo-resource-search">Look up PVO resources</label><br>',
#   '  <input id="v2-pvo-resource-search" type="text" class="ocs__input large gradient" placeholder="Look up a PVO resource...">',
#   '</p>'
# ].join('');
# {% endcapture %}
#
# {% include runners/ui.html
#    runner_id="inputs-hw-v2-popcorn"
#    challenge=challenge1
#    code=code1
#    autostart="true"
# %}

# %% [markdown]
# ## Homework Hack
#
# The PVO volunteer form, where every field has a matching size and style modifier:
#
# * **Volunteer First Name:** `ocs__input small`, because it only needs a few letters
# * **Volunteer Email:** `ocs__input medium`, a regular field set to `type="email"`
# * **Assistance Category:** `ocs__input large gradient`, the field that matters most

# %% [markdown]
# {% capture challenge2 %}
# Homework Hack: the PVO volunteer form using ocs__input with size and gradient modifiers. Hit Run and type something in each field.
# {% endcapture %}
#
# {% capture code2 %}
# // Update the HTML inside the quotes, then hit Run.
# outputElement.innerHTML = [
#   '<p>',
#   '  <label for="v2-volunteer-first-name">Your first name</label><br>',
#   '  <input id="v2-volunteer-first-name" type="text" class="ocs__input small" placeholder="Your First Name">',
#   '</p>',
#   '<p>',
#   '  <label for="v2-volunteer-email">Your email</label><br>',
#   '  <input id="v2-volunteer-email" type="email" class="ocs__input medium" placeholder="Your Email">',
#   '</p>',
#   '<p>',
#   '  <label for="v2-assistance-category">What kind of help?</label><br>',
#   '  <input id="v2-assistance-category" type="text" class="ocs__input large gradient" placeholder="Kind of Help">',
#   '</p>'
# ].join('');
# {% endcapture %}
#
# {% include runners/ui.html
#    runner_id="inputs-hw-v2-homework"
#    challenge=challenge2
#    code=code2
#    autostart="true"
# %}
